# %%
# configure image-magick
from moviepy.config import change_settings
change_settings({"IMAGEMAGICK_BINARY": r"C:\Program Files\ImageMagick-7.1.1-Q16-HDRI\magick.exe"})

import moviepy.editor as mpy
import IPython.display as ipd # Disp. video in notebook
from glob import glob # List all files in a dir

# %%
sound_effect = mpy.AudioFileClip("514987__klankbeeld__park-spring-9am-nl-loonse-en-drunense-duinen-200425_0164.ogg")\
               .subclip("00:00:05.00", "00:00:29.00").volumex(5)

# Save the subclip to a new file.
sound_effect.write_audiofile("subclip.ogg")
# Out:
# MoviePy - Writing audio in subclip.ogg
# MoviePy - Done.

# %%
ipd.Audio("subclip.ogg")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>
